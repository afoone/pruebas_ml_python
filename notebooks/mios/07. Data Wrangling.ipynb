# %% [markdown]
# # Data Wrangling

# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/customer-churn-model/Customer Churn Model.txt')

# %% [markdown]
# # Crear un subconjunto de datos

# %%
account_length = df['Account Length']

# %%
# Esto ya es de tipo 'Series'
type(account_length)
# Out:
# pandas.core.series.Series

# %%
subset = df[['Account Length', 'Phone', 'Day Calls']]

# %%
subset.head()
# Out:
#    Account Length     Phone  Day Calls
# 0             128  382-4657        110
# 1             107  371-7191        123
# 2             137  358-1921        114
# 3              84  375-9999         71
# 4              75  330-6626        113

# %%
type(subset) # Este sí es un dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# Podemos crear una lista de los datos 
desired_colums = ["Account Length", "Phone", "Eve Charge", "Night Calls"]
subset2 = df[desired_colums]

# %%
subset2.tail()
# Out:
#       Account Length     Phone  Eve Charge  Night Calls
# 3328             192  414-4276       18.32           83
# 3329              68  370-3271       13.04          123
# 3330              28  328-8230       24.55           91
# 3331             184  364-6381       13.57          137
# 3332              74  400-4344       22.60           77

# %% [markdown]
# Podemos también borrar directamente las columnas que no nos interesan

# %%
undesired_colums = ["VMail Plan", "VMail Message"]
all_columns_list = df.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
# Este código elminina de una lista los elementos de la otra
sublist = [x for x in all_columns_list if x not in undesired_colums]
sublist
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
# Por fin elimino los elementos que no quería
df = df[sublist]
df.head()
# Con este pequeño truco elimino las columnas que no quería
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 0    KS             128        415  382-4657         no     265.1        110
# 1    OH             107        415  371-7191         no     161.6        123
# 2    NJ             137        415  358-1921         no     243.4        114
# 3    OH              84        408  375-9999        yes     299.4         71
# 4    OK              75        415  330-6626        yes     166.7        113
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
# ...

# %%
# Seleccionando filas
df[0:24]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 0     KS             128        415  382-4657         no     265.1        110
# 1     OH             107        415  371-7191         no     161.6        123
# 2     NJ             137        415  358-1921         no     243.4        114
# 3     OH              84        408  375-9999        yes     299.4         71
# 4     OK              75        415  330-6626        yes     166.7        113
# 5     AL             118        510  391-8027        yes     223.4         98
# 6     MA             121        510  355-9993         no     218.2         88
# 7     MO             147        415  329-9001        yes     157.0         79
# 8     LA             117        408  335-4719         no     184.5         97
# 9     WV             141        415  330-8173        yes     258.6         84
# 10    IN              65        415  329-6603         no     129.1        137
# ...

# %%
# si no ponemos uno será el primero o el último
df[:3]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 0    KS             128        415  382-4657         no     265.1        110
# 1    OH             107        415  371-7191         no     161.6        123
# 2    NJ             137        415  358-1921         no     243.4        114
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0         11.01       10.0           3         2.70               1  False.
# 1         11.45       13.7           3         3.70               1  False.
# 2          7.32       12.2           5         3.29               0  False.

# %%
df[:2]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 0    KS             128        415  382-4657         no     265.1        110
# 1    OH             107        415  371-7191         no     161.6        123
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0         11.01       10.0           3          2.7               1  False.
# 1         11.45       13.7           3          3.7               1  False.

# %%
# o cualquier cosa...
df[4:7]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 4    OK              75        415  330-6626        yes     166.7        113
# 5    AL             118        510  391-8027        yes     223.4         98
# 6    MA             121        510  355-9993         no     218.2         88
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 4       28.34     148.3        122       12.61       186.9          121
# 5       37.98     220.6        101       18.75       203.9          118
# 6       37.09     348.5        108       29.62       212.6          118
#
#    Night Charge  Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 4          8.41       10.1           3         2.73               3  False.
# 5          9.18        6.3           6         1.70               0  False.
# 6          9.57        7.5           7         2.03               3  False.

# %%
# Otro hecho es hacer un formato de filas condicional 
# Filtrar las filas que cumplan una condicion

# Hay que tener en cuenta que lo siguiente nos da una lista boleana
df['Day Mins'] > 300
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Day Mins, Length: 3333, dtype: bool

# %%
# Por lo tanto ahora sí puedo filtrar
df[df['Day Mins']>300]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan  Day Mins  \
# 15      NY             161        415  351-7269         no     332.9
# 76      DC              82        415  374-5353         no     300.3
# 156     OH              83        415  370-9116         no     337.4
# 197     TX             208        510  378-3625         no     326.5
# 230     MD              93        408  360-3324        yes     312.0
# 289     OK              89        510  352-6976         no     303.9
# 365     CO             154        415  343-5709         no     350.8
# 534     LA              67        510  373-6784         no     310.4
# 575     SD             114        415  351-7369         no     309.9
# 605     MO             112        415  373-2053         no     335.5
# 688     MN              13        510  338-7120         no     315.6
# 732     IN              48        510  342-6696         no     300.4
# 815     KY              75        415  341-1191         no     314.6
# ...

# %%
# Vamos a seleccionar ahora usuarios de NYC
df[df['State'] == 'NY']
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan  Day Mins  \
# 15      NY             161        415  351-7269         no     332.9
# 77      NY             144        408  360-1171         no      61.6
# 136     NY              75        415  374-8525         no     175.8
# 182     NY              67        408  405-2888         no     115.6
# 186     NY             106        408  422-1471         no     158.7
# ...    ...             ...        ...       ...        ...       ...
# 3219    NY             150        415  421-6268         no     139.6
# 3227    NY             209        415  369-8703         no     153.7
# 3257    NY             171        415  412-6245         no     137.5
# 3275    NY             120        510  405-5083         no     128.5
# 3310    NY              94        415  363-1123         no     190.4
#
#       Day Calls  Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  \
# ...

# %%
# Condiciones de AND
df[(df['State'] == "NY") & (df['Day Mins'] > 300)]
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan  Day Mins  \
# 15     NY             161        415  351-7269         no     332.9
# 985    NY              64        415  345-9140        yes     346.8
#
#      Day Calls  Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  \
# 15          67       56.59     317.8         97       27.01       160.6
# 985         55       58.96     249.5         79       21.21       275.4
#
#      Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 15           128          7.23        5.4           9         1.46
# 985          102         12.39       13.3           9         3.59
#
#      CustServ Calls Churn?
# 15                4  True.
# 985               1  True.

# %%
# Condiciones de OR
df[(df['State'] == "NY") | (df['Day Mins'] > 300)]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan  Day Mins  \
# 15      NY             161        415  351-7269         no     332.9
# 76      DC              82        415  374-5353         no     300.3
# 77      NY             144        408  360-1171         no      61.6
# 136     NY              75        415  374-8525         no     175.8
# 156     OH              83        415  370-9116         no     337.4
# ...    ...             ...        ...       ...        ...       ...
# 3227    NY             209        415  369-8703         no     153.7
# 3257    NY             171        415  412-6245         no     137.5
# 3275    NY             120        510  405-5083         no     128.5
# 3310    NY              94        415  363-1123         no     190.4
# 3322    MD              62        408  409-1856         no     321.1
#
#       Day Calls  Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  \
# ...

# %%
df[ df['Day Calls'] < df['Night Calls']]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan  Day Mins  \
# 3       OH              84        408  375-9999        yes     299.4
# 4       OK              75        415  330-6626        yes     166.7
# 5       AL             118        510  391-8027        yes     223.4
# 6       MA             121        510  355-9993         no     218.2
# 7       MO             147        415  329-9001        yes     157.0
# ...    ...             ...        ...       ...        ...       ...
# 3325    OH              78        408  368-8555         no     193.4
# 3327    SC              79        415  348-3830         no     134.7
# 3328    AZ             192        415  414-4276         no     156.2
# 3329    WV              68        415  370-3271         no     231.1
# 3331    CT             184        510  364-6381        yes     213.8
#
#       Day Calls  Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  \
# ...

# %% [markdown]
# ## Hacer subconjunto de filas y columnas a la vez

# %%
## Minutos de día, de noche y longitud de los primeros 50 individuos
subset_first_fifty = df [['Day Mins', "Night Mins", "Account Length"]][0:50]

# %%
subset_first_fifty.describe()
# Out:
#          Day Mins  Night Mins  Account Length
# count   50.000000   50.000000       50.000000
# mean   173.480000  194.408000       99.600000
# std     56.302438   55.125896       41.963541
# min     62.400000   70.600000       12.000000
# 25%    129.525000  162.725000       66.750000
# 50%    169.900000  192.550000       96.000000
# 75%    211.825000  224.800000      135.750000
# max    332.900000  326.400000      174.000000

# %%
subset_first_fifty.head()
# Out:
#    Day Mins  Night Mins  Account Length
# 0     265.1       244.7             128
# 1     161.6       254.4             107
# 2     243.4       162.6             137
# 3     299.4       196.9              84
# 4     166.7       186.9              75

# %%
subset_first_fifty.tail()
# Out:
#     Day Mins  Night Mins  Account Length
# 45     120.9       163.1              59
# 46     211.3       134.7              65
# 47     187.0       242.2             142
# 48     159.1       143.2             119
# 49     133.2        70.6              97

# %% [markdown]
# Otro modo efectivo que se puede utilizar pero ha ido cambiando bastante es utilizar la sintaxis loc e iloc

# %%
df.iloc[0:5, 3:6]
# Out:
#       Phone Int'l Plan  Day Mins
# 0  382-4657         no     265.1
# 1  371-7191         no     161.6
# 2  358-1921         no     243.4
# 3  375-9999        yes     299.4
# 4  330-6626        yes     166.7

# %%
df.iloc[:,3:6]
# Out:
#          Phone Int'l Plan  Day Mins
# 0     382-4657         no     265.1
# 1     371-7191         no     161.6
# 2     358-1921         no     243.4
# 3     375-9999        yes     299.4
# 4     330-6626        yes     166.7
# ...        ...        ...       ...
# 3328  414-4276         no     156.2
# 3329  370-3271         no     231.1
# 3330  328-8230         no     180.8
# 3331  364-6381        yes     213.8
# 3332  400-4344         no     234.4
#
# [3333 rows x 3 columns]

# %%
df.iloc[:5, :]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 0    KS             128        415  382-4657         no     265.1        110
# 1    OH             107        415  371-7191         no     161.6        123
# 2    NJ             137        415  358-1921         no     243.4        114
# 3    OH              84        408  375-9999        yes     299.4         71
# 4    OK              75        415  330-6626        yes     166.7        113
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
# ...

# %%
# loc es cuando el indexado no es por posidion sino por etiquetas

df.loc[[1,5, 8, 33], ["Area Code", "Day Mins"]]
# Out:
#     Area Code  Day Mins
# 1         415     161.6
# 5         510     223.4
# 8         408     184.5
# 33        408     249.6

# %%
# Muchas veces tendremos que crear una nueva columna, como total mins
df['Total Mins'] = df['Day Mins'] + df['Night Mins'] + df['Eve Mins']

# %%
df.head() # ya tenemos los  minutos totales
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 0    KS             128        415  382-4657         no     265.1        110
# 1    OH             107        415  371-7191         no     161.6        123
# 2    NJ             137        415  358-1921         no     243.4        114
# 3    OH              84        408  375-9999        yes     299.4         71
# 4    OK              75        415  330-6626        yes     166.7        113
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
# ...

# %%
df['Total Calls'] = df['Day Calls'] + df['Night Calls'] + df['Eve Calls']

# %%
df[2:8]
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan  Day Mins  Day Calls  \
# 2    NJ             137        415  358-1921         no     243.4        114
# 3    OH              84        408  375-9999        yes     299.4         71
# 4    OK              75        415  330-6626        yes     166.7        113
# 5    AL             118        510  391-8027        yes     223.4         98
# 6    MA             121        510  355-9993         no     218.2         88
# 7    MO             147        415  329-9001        yes     157.0         79
#
#    Day Charge  Eve Mins  Eve Calls  ...  Night Mins  Night Calls  \
# 2       41.38     121.2        110  ...       162.6          104
# 3       50.90      61.9         88  ...       196.9           89
# 4       28.34     148.3        122  ...       186.9          121
# 5       37.98     220.6        101  ...       203.9          118
# 6       37.09     348.5        108  ...       212.6          118
# ...

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.describe()
# Out:
#        Account Length    Area Code     Day Mins    Day Calls   Day Charge  \
# count     3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean       101.064806   437.182418   179.775098   100.435644    30.562307
# std         39.822106    42.371290    54.467389    20.069084     9.259435
# min          1.000000   408.000000     0.000000     0.000000     0.000000
# 25%         74.000000   408.000000   143.700000    87.000000    24.430000
# 50%        101.000000   415.000000   179.400000   101.000000    30.500000
# 75%        127.000000   510.000000   216.400000   114.000000    36.790000
# max        243.000000   510.000000   350.800000   165.000000    59.640000
#
#           Eve Mins    Eve Calls   Eve Charge   Night Mins  Night Calls  \
# count  3333.000000  3333.000000  3333.000000  3333.000000  3333.000000
# mean    200.980348   100.114311    17.083540   200.872037   100.107711
# std      50.713844    19.922625     4.310668    50.573847    19.568609
# ...
