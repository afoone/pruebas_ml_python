# %% [markdown]
# # Carga de datos a través de la función open

# %%
import pandas as pd
import os

# %%
mainpath = "/home/atienda/desarrollo/cursos/machine_learning/python-ml-course/datasets"
fullpath = os.path.join(mainpath, filename)

# %%
data3 = open(mainpath + "/" + "customer-churn-model/Customer Churn Model.txt",'r')
# La r es para sólo lectura

# %%
cols = data3.readline().strip().split(",")
n_cols = len(cols)

# %%
print(n_cols)
print(cols)
# Out:
# 21
# ['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan", 'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls', 'Intl Charge', 'CustServ Calls', 'Churn?']

# %%
counter = 0;
main_dict ={}
for col in cols:
    main_dict[col] = []

main_dict
# Out:
# {'State': [],
#  'Account Length': [],
#  'Area Code': [],
#  'Phone': [],
#  "Int'l Plan": [],
#  'VMail Plan': [],
#  'VMail Message': [],
#  'Day Mins': [],
#  'Day Calls': [],
#  'Day Charge': [],
#  'Eve Mins': [],
#  'Eve Calls': [],
#  'Eve Charge': [],
#  'Night Mins': [],
#  'Night Calls': [],
#  'Night Charge': [],
#  'Intl Mins': [],
#  'Intl Calls': [],
#  'Intl Charge': [],
#  'CustServ Calls': [],
#  'Churn?': []}

# %%
for line in data3:
    value = line.strip().split(',');
    for i in range (n_cols):
        main_dict[cols[i]].append(value[i])
    counter += 1
    
print ("El dataset tiene %d filas y %d columnas"%(counter, n_cols))
# Out:
# El dataset tiene 3330 filas y 21 columnas

# %%
df = pd.DataFrame(main_dict)
df.head()
# Out:
#   State Account Length Area Code     Phone Int'l Plan VMail Plan  \
# 0    OH             84       408  375-9999        yes         no
# 1    OK             75       415  330-6626        yes         no
# 2    AL            118       510  391-8027        yes         no
# 3    MA            121       510  355-9993         no        yes
# 4    MO            147       415  329-9001        yes         no
#
#   VMail Message    Day Mins Day Calls Day Charge  ... Eve Calls Eve Charge  \
# 0             0  299.400000        71  50.900000  ...        88   5.260000
# 1             0  166.700000       113  28.340000  ...       122  12.610000
# 2             0  223.400000        98  37.980000  ...       101  18.750000
# 3            24  218.200000        88  37.090000  ...       108  29.620000
# 4             0  157.000000        79  26.690000  ...        94   8.760000
#
#    Night Mins Night Calls Night Charge  Intl Mins Intl Calls Intl Charge  \
# 0  196.900000          89     8.860000   6.600000          7    1.780000
# 1  186.900000         121     8.410000  10.100000          3    2.730000
# 2  203.900000         118     9.180000   6.300000          6    1.700000
# 3  212.600000         118     9.570000   7.500000          7    2.030000
# 4  211.800000          96     9.530000   7.100000          6    1.920000
#
#   CustServ Calls  Churn?
# 0              2  False.
# 1              3  False.
# 2              0  False.
# 3              3  False.
# 4              0  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Escribiendo datos

# %%
infile = mainpath + "/" + "customer-churn-model/Customer Churn Model.txt"
outfile = mainpath + "/" + "customer-churn-model/Customer Churn Model Tabs.txt"

# %%
with open(infile, "r") as infile1:
    with open(outfile, "w") as outfile1:
        for line in infile1:
            fields = line.strip().split(',')
            outfile1.write('\t'.join(fields))
            outfile1.write('\n');

# %%
otrodf = pd.read_csv(outfile, sep = "\t")

# %%
otrodf.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# # Leer datos de una URL

# %%
medalsurl = "http://winterolympicsmedals.com/medals.csv"

# %%
medalsdf = pd.read_csv(medalsurl)
medalsdf.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
# cargamos las librerías de csv y urllib
import csv
import urllib3

# %%
def downloadFromURL(url, filename, sep = ",", delim = "\n", encoding="utf-8", 
                   mainpath = "/Users/JuanGabriel/Developer/AnacondaProjects/python-ml-course/datasets"):
    #primero importamos la librería y hacemos la conexión con la web de los datos
    import urllib3
    http = urllib3.PoolManager()
    r = http.request('GET', url)
    print("El estado de la respuesta es %d" %(r.status))
    response = r.data ## CORREGIDO: eliminado un doble decode que daba error
    
    #El objeto reponse contiene un string binario, así que lo convertimos a un string descodificándolo en UTF-8
    str_data = response.decode(encoding)

    #Dividimos el string en un array de filas, separándolo por intros
    lines = str_data.split(delim)

    #La primera línea contiene la cabecera, así que la extraemos
    col_names = lines[0].split(sep)
    n_cols = len(col_names)

    #Generamos un diccionario vacío donde irá la información procesada desde la URL externa
    counter = 0
    main_dict = {}
    for col in col_names:
        main_dict[col] = []

    #Procesamos fila a fila la información para ir rellenando el diccionario con los datos como hicimos antes
    for line in lines:
        #Nos saltamos la primera línea que es la que contiene la cabecera y ya tenemos procesada
        if(counter > 0):
            #Dividimos cada string por las comas como elemento separador
            values = line.strip().split(sep)
            #Añadimos cada valor a su respectiva columna del diccionario
            for i in range(len(col_names)):
                main_dict[col_names[i]].append(values[i])
        counter += 1

    print("El data set tiene %d filas y %d columnas"%(counter, n_cols))

    #Convertimos el diccionario procesado a Data Frame y comprobamos que los datos son correctos
    df = pd.DataFrame(main_dict)
    print(df.head())

    #Elegimos donde guardarlo (en la carpeta athletes es donde tiene más sentido por el contexto del análisis)
    fullpath = os.path.join(mainpath, filename)

    #Lo guardamos en CSV, en JSON o en Excel según queramos
    df.to_csv(fullpath+".csv")
    df.to_json(fullpath+".json")
    df.to_excel(fullpath+".xls")
    print("Los ficheros se han guardado correctamente en: "+fullpath)
    
    return df

# %% [markdown]
# # Ficheros excel

# %%
print(mainpath+"/titanic/titanic3.xls")
exceldf = pd.read_excel(mainpath+"/titanic/titanic3.xls");
exceldf.head()
# Out:
# /home/atienda/desarrollo/cursos/machine_learning/python-ml-course/datasets/titanic/titanic3.xls
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
